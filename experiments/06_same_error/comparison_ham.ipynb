# %% [markdown]
# # HamLib → Azure QDK vs. Qualtran: Multi-Hamiltonian Comparison
#
# Runs Azure and Qualtran resource estimation for **multiple HamLib Hamiltonians**
# and generates a combined 12-subplot visualization (6 metrics × 2 x-axes).
#
# ## Workflow
# ```
# Define Hamiltonians
#   → Load/build circuits (QASM cache)
#   → Run estimators  (or load cached CSVs)
#   → Save per-Hamiltonian comparison CSVs
#   → Combine results
#   → Save combined CSV
#   → Generate 12-subplot figure
# ```
#
# **Caching**: set `SKIP_CACHED = True` to skip estimation for Hamiltonians
# whose per-Hamiltonian CSV already exists under `data/comparisons/`.
# Set to `False` to re-run all estimators.

# %% [markdown]
# ## Imports

# %%
import sys, os
import pathlib

# Locate repo root by walking up until we find the package directory
_search = pathlib.Path.cwd()
for _ in range(8):
    if (_search / "resourceEstimationPipeline").is_dir():
        REPO_ROOT = str(_search)
        break
    _search = _search.parent
else:
    REPO_ROOT = str(pathlib.Path.cwd())

if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

# Notebook output directory — results go here (under group subdirs), QASM cache stays in data/
try:
    NB_DIR = pathlib.Path(__vsc_ipynb_file__).parent.resolve()
except NameError:
    NB_DIR = pathlib.Path.cwd()

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
pd.set_option("display.max_colwidth", 120)
pd.set_option("display.float_format", "{:.4g}".format)

from resourceEstimationPipeline.config import (
    PipelineConfig, HamlibConfig, EvolutionConfig,
    TranspileConfig, AzureConfig, QualtranConfig,
)
from resourceEstimationPipeline.compare.multi_ham import (
    run_multi_hamiltonian,
    save_combined, load_combined,
    save_comparison, load_comparison,
    COMPARISON_COLUMNS,
)
from resourceEstimationPipeline.compare.plotting import plot_multi_ham_comparison

print(f"REPO_ROOT : {REPO_ROOT}")
print(f"NB_DIR    : {NB_DIR}")
print("Imports OK")
# Out:
# REPO_ROOT : /Users/kevinli/Documents/resourceEstimation
# NB_DIR    : /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error
# Imports OK

# %% [markdown]
# ## Configuration
#
# All estimator parameters live in `base_cfg`.
# Per-Hamiltonian parameters (`hdf5_path`, `key_index`) are in `HAMILTONIANS`.

# %%
# ── Estimation flags ──────────────────────────────────────────────────────────
RUN_AZURE     = True   # set False to skip Azure estimation
RUN_QUALTRAN  = True   # set False to skip Qualtran estimation
SKIP_CACHED   = True   # True → load CSV if already saved; False → re-run

# ── Hamiltonians to process ───────────────────────────────────────────────────
# Each entry: {"hdf5_path": ..., "key_index": int} or {"key": "dataset_key"}
# Optional "group" overrides the auto-detected problem type label.
HAMILTONIANS = [
    # Fermi-Hubbard 1D (FH_D-1.hdf5)
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "fermihubbard", "FH_D-1.hdf5"),
        "key_index": 396,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "fermihubbard", "FH_D-1.hdf5"),
        "key_index": 704,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "fermihubbard", "FH_D-1.hdf5"),
        "key_index": 39,
    },
    # Bose-Hubbard 1D (BH_D-1_d-4.hdf5)
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "bosehubbard", "BH_D-1_d-4.hdf5"),
        "key_index": 585,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "bosehubbard", "BH_D-1_d-4.hdf5"),
        "key_index": 30,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "bosehubbard", "BH_D-1_d-4.hdf5"),
        "key_index": 300,
    },
    # Heisenberg (heis.hdf5)
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "heisenberg", "heis.hdf5"),
        "key_index": 273,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "heisenberg", "heis.hdf5"),
        "key_index": 14,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "heisenberg", "heis.hdf5"),
        "key_index": 123,
    },
    {
        "hdf5_path": os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "heisenberg", "heis.hdf5"),
        "key_index": 268,
    },
]

# ── Base estimator configuration ──────────────────────────────────────────────
base_cfg = PipelineConfig(
    evolution=EvolutionConfig(
        evolution_time=1.0,
        synthesis_order=2,
        synthesis_reps=10,
    ),
    transpile=TranspileConfig(
        optimization_level=1,
        seed_transpiler=42,
        rotation_synthesis_enabled=False,
        rotation_synthesis_epsilon=1e-4,
        synthesis_strategy="synth",
        synthesis_method="bqskit",
    ),
    azure=AzureConfig(
        error_budget=0.01,
        error_rate=1e-3,
        gate_time_ns=50.0,
        measurement_time_ns=100.0,
        factory_type="RoundBased",
        slow_down_factors=[1.0],
        optimization_level=1,
        use_graph=True,
        minimize="qubit_hours",
        pareto_index=0,
    ),
    qualtran=QualtranConfig(
        data_d=23,
        phys_err=1e-3,
        error_budget=0.01,
        data_block="fast",
        factory_type="15to1",
        n_factories=10,
        use_gidney_fowler=False,
        use_beverland=True,
        use_azure_parameters=False,
        optimize_factory=True,
        optimize_factory_d_max=50,
        pareto_index=0,
    ),
)

print(f"{len(HAMILTONIANS)} Hamiltonians configured.")
for i, spec in enumerate(HAMILTONIANS):
    from resourceEstimationPipeline.compare.multi_ham import _detect_group
    grp = spec.get("group") or _detect_group(spec["hdf5_path"])
    print(f"  [{i:2d}] [{grp}]  {os.path.basename(spec['hdf5_path'])}  "
          f"idx={spec.get('key_index')}  key={spec.get('key')}")
# Out:
# 10 Hamiltonians configured.
#   [ 0] [fermihubbard]  FH_D-1.hdf5  idx=396  key=None
#   [ 1] [fermihubbard]  FH_D-1.hdf5  idx=704  key=None
#   [ 2] [fermihubbard]  FH_D-1.hdf5  idx=39  key=None
#   [ 3] [bosehubbard]  BH_D-1_d-4.hdf5  idx=585  key=None
#   [ 4] [bosehubbard]  BH_D-1_d-4.hdf5  idx=30  key=None
#   [ 5] [bosehubbard]  BH_D-1_d-4.hdf5  idx=300  key=None
#   [ 6] [heisenberg]  heis.hdf5  idx=273  key=None
#   [ 7] [heisenberg]  heis.hdf5  idx=14  key=None
#   [ 8] [heisenberg]  heis.hdf5  idx=123  key=None
#   [ 9] [heisenberg]  heis.hdf5  idx=268  key=None

# %% [markdown]
# ## Run estimators (or load cached results)
#
# For each Hamiltonian:
# 1. Load/build circuit (QASM cache — fast)
# 2. If `SKIP_CACHED=True` and a per-Hamiltonian CSV exists, load it instead of running estimators
# 3. Otherwise run Azure and/or Qualtran, save CSV
#
# Individual failures do not abort the loop.

# %%
combined_df = run_multi_hamiltonian(
    ham_specs=HAMILTONIANS,
    base_cfg=base_cfg,
    run_azure=RUN_AZURE,
    run_qualtran=RUN_QUALTRAN,
    skip_cached=SKIP_CACHED,
    out_dir=NB_DIR,
)

print(f"\nTotal rows collected: {len(combined_df)}")
if not combined_df.empty:
    print(combined_df.groupby(["group", "ham_key", "estimator"])[["total_qubits", "runtime", "t_count"]].first().to_string())
# Out:
# ============================================================
# [1/10] [fermihubbard]  idx=396  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk', nqubits=4, n_terms=4, one_norm=2.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/fermihubbard/FH_D-1/passthrough_396.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=1110, T=0, Rz=450, Clifford=1020
# [4/6] Azure QDK: phys_qubits=2,475, runtime=0.0031s
# [5/6] Qualtran: phys_qubits=8,736, runtime=0.0126s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/comparison_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/summary_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk.csv
#
# ============================================================
# [2/10] [fermihubbard]  idx=704  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity', nqubits=10, n_terms=16, one_norm=8.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/fermihubbard/FH_D-1/passthrough_704.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=4630, T=0, Rz=1890, Clifford=4380
# [4/6] Azure QDK: phys_qubits=7,290, runtime=0.0168s
# [5/6] Qualtran: phys_qubits=17,166, runtime=0.0620s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/comparison_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/summary_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity.csv
#
# ============================================================
# [3/10] [fermihubbard]  idx=39  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk', nqubits=20, n_terms=67, one_norm=138.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/fermihubbard/FH_D-1/passthrough_39.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=18720, T=0, Rz=14250, Clifford=32180
# [4/6] Azure QDK: phys_qubits=18,258, runtime=0.0592s
# [5/6] Qualtran: phys_qubits=34,596, runtime=0.4533s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/comparison_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/summary_fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk.csv
#
# ============================================================
# [4/10] [bosehubbard]  idx=585  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4', nqubits=10, n_terms=144, one_norm=189.59591794226557)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4/passthrough_585.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=126090, T=0, Rz=69990, Clifford=150420
# [4/6] Azure QDK: phys_qubits=10,170, runtime=0.2132s
# [5/6] ERROR (Qualtran): No (d_X, d_Z, d_m) up to d_max=50 keeps total_error under 1.000e-02 (factory 1.008e-02 + data_block 0 + rotation 3.333e-03).
# [6/6] Comparison: 28 shared metrics, 0 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/comparison_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/summary_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4.csv
#
# ============================================================
# [5/10] [bosehubbard]  idx=30  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4', nqubits=20, n_terms=319, one_norm=389.09081537009865)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4/passthrough_30.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=283090, T=0, Rz=157290, Clifford=338020
# [4/6] Azure QDK: phys_qubits=24,306, runtime=0.5499s
# [5/6] ERROR (Qualtran): No (d_X, d_Z, d_m) up to d_max=50 keeps total_error under 1.000e-02 (factory 2.263e-02 + data_block 0 + rotation 3.333e-03).
# [6/6] Comparison: 28 shared metrics, 0 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/comparison_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/summary_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4.csv
#
# ============================================================
# [6/10] [bosehubbard]  idx=300  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4', nqubits=52, n_terms=879, one_norm=1027.4744871391563)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4/passthrough_300.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=785490, T=0, Rz=436650, Clifford=938340
# [4/6] Azure QDK: phys_qubits=74,802, runtime=1.7257s
# [5/6] ERROR (Qualtran): No (d_X, d_Z, d_m) up to d_max=50 keeps total_error under 1.000e-02 (factory 6.279e-02 + data_block 0 + rotation 3.333e-03).
# [6/6] Comparison: 28 shared metrics, 0 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/comparison_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/summary_bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4.csv
#
# ============================================================
# [7/10] [heisenberg]  idx=273  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0', nqubits=5, n_terms=12, one_norm=12.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/heisenberg/heis/passthrough_273.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=8290, T=0, Rz=4530, Clifford=9520
# [4/6] Azure QDK: phys_qubits=4,398, runtime=0.0124s
# [5/6] Qualtran: phys_qubits=11,766, runtime=0.1148s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/comparison_graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/summary_graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0.csv
#
# ============================================================
# [8/10] [heisenberg]  idx=14  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0', nqubits=10, n_terms=27, one_norm=27.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/heisenberg/heis/passthrough_14.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=18790, T=0, Rz=10230, Clifford=21520
# [4/6] Azure QDK: phys_qubits=7,290, runtime=0.0326s
# [5/6] Qualtran: phys_qubits=20,724, runtime=0.2947s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/comparison_graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/summary_graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0.csv
#
# ============================================================
# [9/10] [heisenberg]  idx=123  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2', nqubits=20, n_terms=77, one_norm=97.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/heisenberg/heis/passthrough_123.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=40080, T=0, Rz=22830, Clifford=47940
# [4/6] Azure QDK: phys_qubits=18,258, runtime=0.0861s
# [5/6] Qualtran: phys_qubits=42,372, runtime=0.7641s
# [6/6] Comparison: 26 shared metrics, 16 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/comparison_graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/summary_graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2.csv
#
# ============================================================
# [10/10] [heisenberg]  idx=268  key=None
# ============================================================
# [1/6] Loaded Hamiltonian: HamiltonianData(key='graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5', nqubits=50, n_terms=197, one_norm=172.0)
# [2/6] Cache hit (passthrough) — skipping evolution and synthesis.
# [cache] Loaded ← /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/data/hamlib/condensedmatter/heisenberg/heis/passthrough_268.qasm
# [3/6] (skipped — loaded from passthrough cache): depth=103080, T=0, Rz=58830, Clifford=123540
# [4/6] Azure QDK: phys_qubits=54,389, runtime=0.2693s
# [5/6] ERROR (Qualtran): No (d_X, d_Z, d_m) up to d_max=50 keeps total_error under 1.000e-02 (factory 9.063e-03 + data_block 0 + rotation 3.333e-03).
# [6/6] Comparison: 28 shared metrics, 0 numeric differences.
#   Side-by-side → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/comparison_graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5.csv
#   Summary      → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/summary_graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5.csv
#
# Total rows collected: 16
#                                                                                    total_qubits  runtime  t_count
# group        ham_key                                                    estimator
# bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4 Azure             24306   0.5499  2516640
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4 Azure             74802    1.726  6986400
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4  Azure             10170   0.2132  1119840
# fermihubbard fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk       Azure             18258   0.0592   213750
#                                                                         Qualtran          34596   0.4533   103020
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk         Azure              2475 0.003087     5850
#                                                                         Qualtran           8736  0.01258     3080
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity     Azure              7290  0.01682    26460
#                                                                         Qualtran          17166  0.06204    14100
# heisenberg   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0                  Azure              7290  0.03265   153450
#                                                                         Qualtran          20724   0.2947    63040
#              graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2                  Azure             18258  0.08613   342450
#                                                                         Qualtran          42372   0.7641   155380
#              graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5                Azure             54389   0.2693   941280
#              graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0                   Azure              4398   0.0124    58890
#                                                                         Qualtran          11766   0.1148    27840

# %% [markdown]
# ## Save combined results
#
# Saves to `data/comparisons/all_comparisons.csv`.
# The plots can be regenerated from this file without re-running estimators.

# %%
if not combined_df.empty:
    combined_path = save_combined(combined_df, out_dir=NB_DIR)
    print(f"Combined CSV → {combined_path}")
else:
    print("No results to save — check estimator errors above.")
# Out:
# Combined CSV → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/all_comparisons.csv

# %% [markdown]
# ## (Optional) Load from combined CSV
#
# Run this cell instead of the estimation cells above to regenerate plots
# from previously saved results.

# %%
# Uncomment to load without re-running estimators:
# combined_df = load_combined(out_dir=NB_DIR)
# if combined_df is None:
#     print("No combined CSV found — run estimators first.")
# else:
#     print(f"Loaded {len(combined_df)} rows from combined CSV.")
#     display(combined_df)
print("(cell skipped — using in-memory combined_df from estimation step)")
# Out:
# (cell skipped — using in-memory combined_df from estimation step)

# %% [markdown]
# ## Inspect combined DataFrame

# %%
if combined_df.empty:
    print("No data — nothing to display.")
else:
    from IPython.display import display
    display(combined_df[COMPARISON_COLUMNS])
# Out:
#            group                                                     ham_key  \
# 0   fermihubbard          fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk
# 1   fermihubbard          fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk
# 2   fermihubbard      fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity
# 3   fermihubbard      fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity
# 4   fermihubbard        fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk
# 5   fermihubbard        fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk
# 6    bosehubbard   bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4
# 7    bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4
# 8    bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4
# 9     heisenberg                    graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0
# 10    heisenberg                    graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0
# 11    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0
# 12    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0
# 13    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2
# 14    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2
# 15    heisenberg                 graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5
#
#                                                                                          hdf5_path  \
# 0      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 1      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 2      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 3      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 4      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 5      /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/fermihubbard/FH_D-1.hdf5
# 6   /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4.hdf5
# 7   /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4.hdf5
# 8   /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/bosehubbard/BH_D-1_d-4.hdf5
# 9          /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 10         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 11         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 12         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 13         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 14         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
# 15         /Users/kevinli/Documents/resourceEstimation/hamlib/condensedmatter/heisenberg/heis.hdf5
#
#     key_index  nqubits estimator  rz_count  logical_qubits  spacetime  \
# 0         396        4     Azure       450               4       7.64
# 1         396        4  Qualtran       450               4      109.9
# 2         704       10     Azure      1890              10      122.7
# 3         704       10  Qualtran      1890              10       1065
# 4          39       20     Azure     14250              20       1081
# 5          39       20  Qualtran     14250              20  1.568e+04
# 6         585       10     Azure     69990              10       2168
# 7          30       20     Azure    157290              20  1.337e+04
# 8         300       52     Azure    436650              52  1.291e+05
# 9         273        5     Azure      4530               5      54.52
# 10        273        5  Qualtran      4530               5       1351
# 11         14       10     Azure     10230              10        238
# 12         14       10  Qualtran     10230              10       6108
# 13        123       20     Azure     22830              20       1573
# 14        123       20  Qualtran     22830              20  3.238e+04
# 15        268       50     Azure     58830              50  1.465e+04
#
#     compute_qubits  factory_qubits  total_qubits  runtime  t_count  \
# 0             2415              60          2475 0.003087     5850
# 1             5070            3666          8736  0.01258     3080
# 2             7230              60          7290  0.01682    26460
# 3            13500            3666         17166  0.06204    14100
# 4            18198              60         18258   0.0592   213750
# 5            31212            3384         34596   0.4533   103020
# 6            10110              60         10170   0.2132  1119840
# 7            24246              60         24306   0.5499  2516640
# 8            72702            2100         74802    1.726  6986400
# 9             4338              60          4398   0.0124    58890
# 10            8100            3666         11766   0.1148    27840
# 11            7230              60          7290  0.03265   153450
# 12           17340            3384         20724   0.2947    63040
# 13           18198              60         18258  0.08613   342450
# 14           38988            3384         42372   0.7641   155380
# 15           54329              60         54389   0.2693   941280
#
#                              estimator_name
# 0   Azure QDK (err_rate=1e-03, budget=0.01)
# 1                  Qualtran (d=13, p=1e-03)
# 2   Azure QDK (err_rate=1e-03, budget=0.01)
# 3                  Qualtran (d=15, p=1e-03)
# 4   Azure QDK (err_rate=1e-03, budget=0.01)
# 5                  Qualtran (d=17, p=1e-03)
# 6   Azure QDK (err_rate=1e-03, budget=0.01)
# 7   Azure QDK (err_rate=1e-03, budget=0.01)
# 8   Azure QDK (err_rate=1e-03, budget=0.01)
# 9   Azure QDK (err_rate=1e-03, budget=0.01)
# 10                 Qualtran (d=15, p=1e-03)
# 11  Azure QDK (err_rate=1e-03, budget=0.01)
# 12                 Qualtran (d=17, p=1e-03)
# 13  Azure QDK (err_rate=1e-03, budget=0.01)
# 14                 Qualtran (d=19, p=1e-03)
# 15  Azure QDK (err_rate=1e-03, budget=0.01)

# %% [markdown]
# ## 12-subplot comparison figure
#
# **Left column** — x: Rz count
# **Right column** — x: Logical qubits
#
# **Rows** (top→bottom): Spacetime, Compute qubits, Factory qubits, Total qubits, Runtime, T count
#
# Each point = one Hamiltonian. Lines connect points belonging to the same estimator,
# sorted by x-value.

# %%
# All-Hamiltonians combined plot
if combined_df.empty:
    print("No data to plot.")
else:
    fig = plot_multi_ham_comparison(
        combined_df,
        figsize=(14, 18),
        title="Azure vs Qualtran — All Hamiltonians",
        log_y=True,
        # annotate_points=True,
    )
    plot_path = NB_DIR / "all_hamiltonians.png"
    plt.savefig(plot_path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"Figure saved → {plot_path}")
# Out:
# Figure saved → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/all_hamiltonians.png

# %%
# Per-group plots — one figure per problem type, saved under NB_DIR/<group>/
if not combined_df.empty:
    for group, grp_df in combined_df.groupby("group"):
        grp_dir = NB_DIR / group
        grp_dir.mkdir(parents=True, exist_ok=True)

        fig = plot_multi_ham_comparison(
            grp_df,
            figsize=(14, 18),
            title=f"Azure vs Qualtran — {group.capitalize()} Hamiltonians",
            log_y=True,
            annotate_points=False,
        )
        plot_path = grp_dir / f"{group}.png"
        plt.savefig(plot_path, dpi=150, bbox_inches="tight")
        plt.show()
        print(f"[{group}] Plot saved → {plot_path}")
# Out:
# [bosehubbard] Plot saved → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/bosehubbard/bosehubbard.png
# [fermihubbard] Plot saved → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/fermihubbard/fermihubbard.png
# [heisenberg] Plot saved → /Users/kevinli/Documents/resourceEstimation/resourceEstimationPipeline/experiments/06_same_error/heisenberg/heisenberg.png

# %% [markdown]
# ## (Optional) Annotated figure — show Hamiltonian labels

# %%
# Uncomment for an annotated version showing ham_key labels on each point:
# if not combined_df.empty:
#     fig2 = plot_multi_ham_comparison(
#         combined_df,
#         figsize=(16, 20),
#         title="Azure vs Qualtran — Annotated",
#         log_y=True,
#         annotate_points=True,
#     )
#     plt.show()
print("(annotated plot cell — uncomment to run)")
# Out:
# (annotated plot cell — uncomment to run)

# %% [markdown]
# ## Per-Hamiltonian summary table

# %%
if not combined_df.empty:
    from IPython.display import display
    import numpy as np

    summary_cols = ["group", "ham_key", "estimator", "rz_count", "logical_qubits",
                    "total_qubits", "compute_qubits", "factory_qubits",
                    "runtime", "t_count", "spacetime"]
    display(combined_df[summary_cols].sort_values(["group", "ham_key", "estimator"]))

    print("\nEstimator coverage per Hamiltonian:")
    pivot = combined_df.pivot_table(
        index=["group", "ham_key"],
        columns="estimator",
        values="total_qubits",
        aggfunc="first",
    )
    display(pivot)
# Out:
#            group                                                     ham_key  \
# 7    bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4
# 8    bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4
# 6    bosehubbard   bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4
# 4   fermihubbard        fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk
# 5   fermihubbard        fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk
# 0   fermihubbard          fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk
# 1   fermihubbard          fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk
# 2   fermihubbard      fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity
# 3   fermihubbard      fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity
# 11    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0
# 12    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0
# 13    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2
# 14    heisenberg                   graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2
# 15    heisenberg                 graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5
# 9     heisenberg                    graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0
# 10    heisenberg                    graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0
#
#    estimator  rz_count  logical_qubits  total_qubits  compute_qubits  \
# 7      Azure    157290              20         24306           24246
# 8      Azure    436650              52         74802           72702
# 6      Azure     69990              10         10170           10110
# 4      Azure     14250              20         18258           18198
# 5   Qualtran     14250              20         34596           31212
# 0      Azure       450               4          2475            2415
# 1   Qualtran       450               4          8736            5070
# 2      Azure      1890              10          7290            7230
# 3   Qualtran      1890              10         17166           13500
# 11     Azure     10230              10          7290            7230
# 12  Qualtran     10230              10         20724           17340
# 13     Azure     22830              20         18258           18198
# 14  Qualtran     22830              20         42372           38988
# 15     Azure     58830              50         54389           54329
# 9      Azure      4530               5          4398            4338
# 10  Qualtran      4530               5         11766            8100
#
#     factory_qubits  runtime  t_count  spacetime
# 7               60   0.5499  2516640  1.337e+04
# 8             2100    1.726  6986400  1.291e+05
# 6               60   0.2132  1119840       2168
# 4               60   0.0592   213750       1081
# 5             3384   0.4533   103020  1.568e+04
# 0               60 0.003087     5850       7.64
# 1             3666  0.01258     3080      109.9
# 2               60  0.01682    26460      122.7
# 3             3666  0.06204    14100       1065
# 11              60  0.03265   153450        238
# 12            3384   0.2947    63040       6108
# 13              60  0.08613   342450       1573
# 14            3384   0.7641   155380  3.238e+04
# 15              60   0.2693   941280  1.465e+04
# 9               60   0.0124    58890      54.52
# 10            3666   0.1148    27840       1351
# Estimator coverage per Hamiltonian:
# estimator                                                                   Azure  \
# group        ham_key
# bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4 2.431e+04
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4  7.48e+04
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4  1.017e+04
# fermihubbard fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk       1.826e+04
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk              2475
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity          7290
# heisenberg   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0                       7290
#              graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2                  1.826e+04
#              graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5                5.439e+04
#              graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0                        4398
#
# estimator                                                                Qualtran
# group        ham_key
# bosehubbard  bh_graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-10_enc-gray_d-4       NaN
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-26_U-10_enc-gray_d-4       NaN
#              bh_graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-10_enc-gray_d-4        NaN
# fermihubbard fh-graph-1D-grid-nonpbc-qubitnodes_Lx-10_U-12_enc-bk        3.46e+04
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-2_U-0_enc-bk              8736
#              fh-graph-1D-grid-nonpbc-qubitnodes_Lx-5_U-0_enc-parity     1.717e+04
# heisenberg   graph-1D-grid-nonpbc-qubitnodes_Lx-10_h-0                  2.072e+04
#              graph-1D-grid-nonpbc-qubitnodes_Lx-20_h-2                  4.237e+04
#              graph-1D-grid-nonpbc-qubitnodes_Lx-50_h-0.5                      NaN
#              graph-1D-grid-nonpbc-qubitnodes_Lx-5_h-0                   1.177e+04

# %% [markdown]
# ## Single-Hamiltonian detailed comparison
#
# The original per-Hamiltonian step-by-step workflow still works — see
# `pipeline.run()` with `run_azure=True, run_qualtran=True` for a single
# `PipelineConfig`, then use `compare.metrics.compare()` and
# `compare.tables.comparison_dataframe()` for the full side-by-side table.

# %%
# Example: run single-Hamiltonian detailed comparison
# Uncomment and set hdf5_path + key_index:
#
# from resourceEstimationPipeline import pipeline
# from resourceEstimationPipeline.compare.metrics import compare, enrich_from_circuit
# from resourceEstimationPipeline.compare.tables import comparison_dataframe
# from resourceEstimationPipeline.config import PipelineConfig, HamlibConfig
#
# single_cfg = PipelineConfig(
#     hamlib=HamlibConfig(
#         hdf5_path=os.path.join(REPO_ROOT, "hamlib", "condensedmatter", "bosehubbard", "BH_D-1_d-4.hdf5"),
#         key_index=30,
#     ),
#     evolution=base_cfg.evolution,
#     transpile=base_cfg.transpile,
#     azure=base_cfg.azure,
#     qualtran=base_cfg.qualtran,
# )
# pr = pipeline.run(single_cfg, run_azure=True, run_qualtran=True)
# if pr.azure_result and pr.clifford_t_circuit:
#     pr.azure_result = enrich_from_circuit(pr.azure_result, pr.clifford_t_circuit)
# if pr.qualtran_result and pr.clifford_t_circuit:
#     pr.qualtran_result = enrich_from_circuit(pr.qualtran_result, pr.clifford_t_circuit)
# report = compare(pr.available_results())
# display(comparison_dataframe(report))
# print("(single-Hamiltonian cell — uncomment to run)")
